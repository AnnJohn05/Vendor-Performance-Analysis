# %%
import pandas as pd
import os
from sqlalchemy import create_engine

# %%
os.listdir('data')
# Out:
# ['begin_inventory.csv',
#  'end_inventory.csv',
#  'purchases.csv',
#  'purchase_prices.csv',
#  'sales.csv',
#  'vendor_invoice.csv']

# %%
engine = create_engine('sqlite:///inventory.db')

# %%
for file in os.listdir('data'):
    if file.endswith('.csv'):
        file_path = os.path.join('data', file)
        df = pd.read_csv(file_path)
        print(file, df.shape)
# Out:
# begin_inventory.csv (206529, 9)
# end_inventory.csv (224489, 9)
# purchases.csv (2372474, 16)
# purchase_prices.csv (12261, 9)
# sales.csv (12825363, 14)
# vendor_invoice.csv (5543, 10)

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite:///inventory.db')

# %%
def ingest_db(df, table_name, engine):
    df.to_sql(table_name, con=engine, if_exists='replace', index=False)

# %%
for file in os.listdir('data'):
    if file.endswith('.csv'):
        file_path = os.path.join('data', file)
        df = pd.read_csv(file_path)
        table_name = file[:-4]  # Removes .csv from the filename
        ingest_db(df, table_name, engine)
        print(f"{file} loaded into SQLite as table '{table_name}'")
# Out:
# begin_inventory.csv loaded into SQLite as table 'begin_inventory'
# end_inventory.csv loaded into SQLite as table 'end_inventory'
# purchases.csv loaded into SQLite as table 'purchases'
# purchase_prices.csv loaded into SQLite as table 'purchase_prices'
# sales.csv loaded into SQLite as table 'sales'
# vendor_invoice.csv loaded into SQLite as table 'vendor_invoice'

# %%
from sqlalchemy import inspect
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['begin_inventory', 'end_inventory', 'purchase_prices', 'purchases', 'sales', 'vendor_invoice']

# %%
import logging
logging.basicConfig(
    filename="logs.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)
